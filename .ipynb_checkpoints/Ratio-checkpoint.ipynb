# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("malicious_url.csv")

# %%
dataset['Uppercase'] = dataset['url'].str.count(r'[A-Z]')
dataset['Lowercase'] = dataset['url'].str.count(r'[a-z]')

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase
# 0          16          0         13
# 1          35          0         29
# 2          31          0         25
# 3          88          0         63
# 4         235         63        136

# %%
dataset['Ratio of Ucase to Lcase'] = dataset['Uppercase'] / dataset['Lowercase']

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase
# 0          16          0         13                 0.000000
# 1          35          0         29                 0.000000
# 2          31          0         25                 0.000000
# 3          88          0         63                 0.000000
# 4         235         63        136                 0.463235

# %%
dataset['Alpha_len'] = (dataset['url'].str.count(r'[A-Z]'))+(dataset['url'].str.count(r'[a-z]'))

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199

# %%
dataset.tail()
# Out:
#         Unnamed: 0                                            url      type  \
# 651186      651186        xbox360.ign.com/objects/850/850402.html  phishing
# 651187      651187   games.teamxbox.com/xbox-360/1860/Dead-Space/  phishing
# 651188      651188     www.gamespot.com/xbox360/action/deadspace/  phishing
# 651189      651189  en.wikipedia.org/wiki/Dead_Space_(video_game)  phishing
# 651190      651190      www.angelfire.com/goth/devilmaycrytonite/  phishing
#
#         url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len
# 651186          39          0         21                 0.000000         21
# 651187          44          2         27                 0.074074         29
# 651188          42          0         33                 0.000000         33
# 651189          45          2         34                 0.058824         36
# 651190          41          0         36                 0.000000         36

# %%
dataset['count_numbers'] = dataset['url'].str.count('\d')

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers
# 0              0
# 1              1
# 2              1
# 3              7
# 4             22

# %%
dataset.tail()
# Out:
#         Unnamed: 0                                            url      type  \
# 651186      651186        xbox360.ign.com/objects/850/850402.html  phishing
# 651187      651187   games.teamxbox.com/xbox-360/1860/Dead-Space/  phishing
# 651188      651188     www.gamespot.com/xbox360/action/deadspace/  phishing
# 651189      651189  en.wikipedia.org/wiki/Dead_Space_(video_game)  phishing
# 651190      651190      www.angelfire.com/goth/devilmaycrytonite/  phishing
#
#         url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 651186          39          0         21                 0.000000         21
# 651187          44          2         27                 0.074074         29
# 651188          42          0         33                 0.000000         33
# 651189          45          2         34                 0.058824         36
# 651190          41          0         36                 0.000000         36
#
#         count_numbers
# 651186             12
# 651187              7
# 651188              3
# 651189              0
# 651190              0

# %%
def D_C_ratio(url):
    count_numbers= sum(item.isdigit() for item in url)
    Char_len=len(url)
    r = count_numbers/Char_len
    return(r)

# %%
dataset['Digits_to_char_ratio'] = dataset['url'].apply(D_C_ratio)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers  Digits_to_char_ratio
# 0              0              0.000000
# 1              1              0.028571
# 2              1              0.032258
# 3              7              0.079545
# 4             22              0.093617

# %%
def U_C_ratio(url):
    Uppercase= sum(item.isupper() for item in url)
    length=len(url)
    ratio = Uppercase/length
    return(ratio)

# %%
dataset['Ucase_to_char_ratio'] = dataset['url'].apply(U_C_ratio)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers  Digits_to_char_ratio  Ucase_to_char_ratio
# 0              0              0.000000             0.000000
# 1              1              0.028571             0.000000
# 2              1              0.032258             0.000000
# 3              7              0.079545             0.000000
# 4             22              0.093617             0.268085

# %%
def L_C_ratio(url):
    Lowercase= sum(item.islower() for item in url)
    length=len(url)
    ratio = Lowercase/length
    return(ratio)

# %%
dataset['Lcase_to_char_ratio'] = dataset['url'].apply(L_C_ratio)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers  Digits_to_char_ratio  Ucase_to_char_ratio  \
# 0              0              0.000000             0.000000
# 1              1              0.028571             0.000000
# 2              1              0.032258             0.000000
# 3              7              0.079545             0.000000
# 4             22              0.093617             0.268085
#
#    Lcase_to_char_ratio
# 0             0.812500
# 1             0.828571
# 2             0.806452
# 3             0.715909
# 4             0.578723

# %%
def No_of_param(url):
    param =url.split('&')
    return len(param)-1

# %%
dataset['No_of_parameters'] = dataset['url'].apply(No_of_param)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers  Digits_to_char_ratio  Ucase_to_char_ratio  \
# 0              0              0.000000             0.000000
# 1              1              0.028571             0.000000
# 2              1              0.032258             0.000000
# 3              7              0.079545             0.000000
# 4             22              0.093617             0.268085
#
#    Lcase_to_char_ratio  No_of_parameters
# 0             0.812500                 0
# 1             0.828571                 0
# 2             0.806452                 0
# 3             0.715909                 3
# 4             0.578723                 2

# %%
import math 
def url_entropy(url):
    s= url.strip()
    prob= [float(s.count(c))/len(s)for c in dict.fromkeys(list(s))]
    entropy= sum([(p * math.log(p)/ math.log(2.0))for p in prob])
    return entropy

# %%
dataset['Url_entropy'] = dataset['url'].apply(url_entropy)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers  Digits_to_char_ratio  Ucase_to_char_ratio  \
# 0              0              0.000000             0.000000
# 1              1              0.028571             0.000000
# 2              1              0.032258             0.000000
# 3              7              0.079545             0.000000
# 4             22              0.093617             0.268085
#
#    Lcase_to_char_ratio  No_of_parameters  Url_entropy
# 0             0.812500                 0    -3.375000
# 1             0.828571                 0    -4.079143
# 2             0.806452                 0    -3.708093
# 3             0.715909                 3    -4.660343
# 4             0.578723                 2    -5.491293

# %%
def has_http(url):
    return 'http:' in url

# %%
dataset['Has_http'] = dataset['url'].apply(has_http)

# %%
from urllib.parse import urlparse
def path_len(url):
    return len(urlparse(url).path)

# %%
dataset['Path_length'] = dataset['url'].apply(path_len)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase  Alpha_len  \
# 0          16          0         13                 0.000000         13
# 1          35          0         29                 0.000000         29
# 2          31          0         25                 0.000000         25
# 3          88          0         63                 0.000000         63
# 4         235         63        136                 0.463235        199
#
#    count_numbers  Digits_to_char_ratio  Ucase_to_char_ratio  \
# 0              0              0.000000             0.000000
# 1              1              0.028571             0.000000
# 2              1              0.032258             0.000000
# 3              7              0.079545             0.000000
# 4             22              0.093617             0.268085
#
#    Lcase_to_char_ratio  No_of_parameters  Url_entropy  Has_http  Path_length
# 0             0.812500                 0    -3.375000     False           16
# 1             0.828571                 0    -4.079143     False           35
# 2             0.806452                 0    -3.708093     False           31
# 3             0.715909                 3    -4.660343      True           10
# 4             0.578723                 2    -5.491293      True           10

# %%
from urllib.parse import urlparse
def host_len(url):
    return len(urlparse(url).netloc)

# %%
dataset['Host_length'] = dataset['url'].apply(host_len)

# %%
def no_of_frags(url):
    frags=url.split('#')
    return len(frags)-1

# %%
dataset['No_of_fragments'] = dataset['url'].apply(no_of_frags)

# %%
def no_of_subdomains(url):
    sd=url.split('http')[-1].split('//')[-1].split('/')
    return len(sd)-1

# %%
dataset['No_of_Subdomains'] = dataset['url'].apply(no_of_subdomains)
